# %%
import sys
import mysql.connector

import pandas as pd
import sys
import mysql.connector
import numpy as np
import os
from dotenv import load_dotenv
load_dotenv()
#ESTE ARGUMENTO NO SE USA EN ESTE REPORTE, SERÁ 0 SIEMPRE UWU
id=0
#configurar la conexion a la base de datos
DB_USERNAME = os.getenv('DB_USERNAME')
DB_DATABASE = os.getenv('DB_DATABASE')
DB_PASSWORD = os.getenv('DB_PASSWORD')
DB_PORT = os.getenv('DB_PORT')
# Conectar a DB
cnx = mysql.connector.connect(user=DB_USERNAME,
                              password=DB_PASSWORD,
                              host='localhost',
                              port=DB_PORT,
                              database=DB_DATABASE,
                              use_pure=False)

# %%
#Tablas paneles
tablas = ['two_in_joist_l_galvanized_panels','two_in_joist_l_painted_panels','two_point_five_in_joist_l_galvanized_panels','two_point_five_in_joist_l_painted_panels','chair_joist_galvanized_panels','chair_joist_l_painted_panels']

# %%
for i in tablas:
    print(i)
    cnx.cursor().execute('alter table '+i+' add column loading_capacity float')
# Out:
# chair_joist_l_painted_panels

# %%
l2=pd.read_excel('l2.xlsx',sheet_name=None)

# %%
dict={0.05,0.1,0.15,0.2,0.35,0.3}
# Out:
#     Unnamed: 0 PANELES METALICOS CALIBRE 24 PARA VIGA "L" DE 2 IN DE PATIN  \
# 0          NaN                                         DESARROLLO
# 1          NaN                                            FONDO M
# 2          NaN                                               0.15
# 3          NaN                                                NaN
# 4          NaN                                                NaN
# 5          NaN                                                0.2
# 6          NaN                                                NaN
# 7          NaN                                                NaN
# 8          NaN                                               0.24
# 9          NaN                                                NaN
# 10         NaN                                                NaN
# 11         NaN                                                0.3
# 12         NaN                                                NaN
# ...

# %%
tablas[0]
# Out:
# 'two_in_joist_l_galvanized_panels'

# %%
#Rellenando por calibre cada tabla, esto lo hago viendo los exceles
#y cambiando el indice de tablas[]
calibre=14
low=170
high=200
cnx.cursor().execute('update '+tablas[0]+' set loading_capacity = '+str(low)+' where background_dimension <= 0.1 and caliber='+str(calibre))
cnx.cursor().execute('update '+tablas[0]+' set loading_capacity = '+str(high)+' where background_dimension > 0.1 and caliber='+str(calibre))
cnx.commit()
